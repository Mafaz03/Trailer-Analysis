# %%
import requests
from bs4 import BeautifulSoup

# IMDb URL for the top 100 movies
url = 'https://www.imdb.com/list/ls055851487/'

# Fetch the HTML content from the IMDb page
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

# Find movie titles
movie_titles = []
for movie in soup.find_all('div', class_='lister-item-content'):
    title = movie.find('a').text.strip()
    movie_titles.append(title)

# Display the list of movie titles
for idx, title in enumerate(movie_titles, start=1):
    print(f"{idx}. {title}")
# Out:
# 1. Dumb and Dumber
# 2. Caddyshack
# 3. National Lampoon's Christmas Vacation
# 4. National Lampoon's Animal House
# 5. Revenge of the Nerds
# 6. Billy Madison
# 7. The Naked Gun: From the Files of Police Squad!
# 8. Airplane!
# 9. Happy Gilmore
# 10. Ace Ventura: When Nature Calls
# 11. Bachelor Party
# 12. Clerks
# 13. Alferd Packer: The Musical
# 14. Bad Santa
# 15. Porky's
# 16. Tommy Boy
# 17. Spaceballs
# 18. Monty Python and the Holy Grail
# 19. Say It Isn't So
# 20. There's Something About Mary
# 21. Mallrats
# 22. Road Trip
# 23. Step Brothers
# 24. Scary Movie
# 25. Me, Myself & Irene
# 26. The Goonies
# 27. Coneheads
# 28. Super Troopers
# 29. Team America: World Police
# 30. Strange Wilderness
# 31. The Great Outdoors
# 32. Fast Times at Ridgemont High
# 33. Office Space
# 34. Son in Law
# 35. The 40 Year Old Virgin
# 36. The Hangover
# 37. Police Academy
# 38. Saving Silverman
# 39. Ferris Bueller's Day Off
# 40. Mrs. Doubtfire
# 41. Bill & Ted's Excellent Adventure
# ...

# %%
movie_titles
# Out:
# ['Dumb and Dumber',
#  'Caddyshack',
#  "National Lampoon's Christmas Vacation",
#  "National Lampoon's Animal House",
#  'Revenge of the Nerds',
#  'Billy Madison',
#  'The Naked Gun: From the Files of Police Squad!',
#  'Airplane!',
#  'Happy Gilmore',
#  'Ace Ventura: When Nature Calls',
#  'Bachelor Party',
#  'Clerks',
#  'Alferd Packer: The Musical',
#  'Bad Santa',
#  "Porky's",
#  'Tommy Boy',
#  'Spaceballs',
#  'Monty Python and the Holy Grail',
#  "Say It Isn't So",
#  "There's Something About Mary",
#  'Mallrats',
#  'Road Trip',
#  'Step Brothers',
#  'Scary Movie',
#  'Me, Myself & Irene',
#  'The Goonies',
#  'Coneheads',
#  'Super Troopers',
#  'Team America: World Police',
#  'Strange Wilderness',
#  'The Great Outdoors',
#  'Fast Times at Ridgemont High',
#  'Office Space',
#  'Son in Law',
#  'The 40 Year Old Virgin',
#  'The Hangover',
#  'Police Academy',
#  'Saving Silverman',
#  "Ferris Bueller's Day Off",
#  'Mrs. Doubtfire',
# ...

# %%
import requests
import csv

API_KEY = 'AIzaSyC30VmGIHkzUOkE4Ifkd7CWKD88piNr2Os'

def get_youtube_trailer_link(movie_title):
    base_url = 'https://www.googleapis.com/youtube/v3/search'
    params = {
        'key': API_KEY,
        'part': 'snippet',
        'q': f'{movie_title} trailer',
        'type': 'video',
        'maxResults': 1
    }

    response = requests.get(base_url, params=params)
    if response.status_code == 200:
        data = response.json()
        if 'items' in data and len(data['items']) > 0:
            video_id = data['items'][0]['id']['videoId']
            return f'https://www.youtube.com/watch?v={video_id}'
    return None


# Collect trailer links for each movie title
movie_trailer_links = []
for title in movie_titles:
    trailer_link = get_youtube_trailer_link(title)
    movie_trailer_links.append((title, trailer_link))

# Write data to a CSV file
with open('links/romantic_movies.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['Movie Title', 'Trailer Link'])
    writer.writerows(movie_trailer_links)

print("CSV file created with movie titles and trailer links.")
# Out:
# CSV file created with movie titles and trailer links.
