# %%
import requests
from bs4 import BeautifulSoup

# IMDb URL for the top 100 movies
url = 'https://www.imdb.com/list/ls076655138/'

# Fetch the HTML content from the IMDb page
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

# Find movie titles
movie_titles = []
for movie in soup.find_all('div', class_='lister-item-content'):
    title = movie.find('a').text.strip()
    movie_titles.append(title)

# Display the list of movie titles
for idx, title in enumerate(movie_titles, start=1):
    print(f"{idx}. {title}")
# Out:
# 1. Die Hard
# 2. Raiders of the Lost Ark
# 3. Indiana Jones and the Temple of Doom
# 4. Indiana Jones and the Last Crusade
# 5. Terminator 2: Judgment Day
# 6. Predator
# 7. Mad Max 2
# 8. RoboCop
# 9. Aliens
# 10. Point Break
# 11. The Rock
# 12. Lethal Weapon
# 13. Speed
# 14. First Blood
# 15. Commando
# 16. Total Recall
# 17. Die Hard with a Vengeance
# 18. Con Air
# 19. Face/Off
# 20. True Lies
# 21. Big Trouble in Little China
# 22. Last Action Hero
# 23. They Live
# 24. The Terminator
# 25. The Matrix
# 26. Rambo: First Blood Part II
# 27. The Mummy
# 28. The Running Man
# 29. The Last Boy Scout
# 30. Pirates of the Caribbean: The Curse of the Black Pearl
# 31. The Dark Knight
# 32. Tango & Cash
# 33. Casino Royale
# 34. Mad Max: Fury Road
# 35. The Bourne Identity
# 36. The Bourne Supremacy
# 37. The Bourne Ultimatum
# 38. Kill Bill: Vol. 2
# 39. Kill Bill: Vol. 1
# 40. Skyfall
# 41. John Wick
# 42. John Wick: Chapter 2
# 43. John Wick: Chapter 3 - Parabellum
# 44. Mission: Impossible - Ghost Protocol
# 45. Serbuan maut
# 46. Serbuan maut 2: Berandal
# 47. Taken
# 48. Inception
# 49. Top Gun: Maverick
# 50. Top Gun
# 51. Léon
# 52. Heat
# 53. The Fugitive
# 54. Under Siege
# 55. Cliffhanger
# 56. Demolition Man
# 57. Independence Day
# 58. The Long Kiss Goodnight
# 59. Armageddon
# 60. Air Force One
# 61. Red Heat
# 62. Timecop
# 63. Bloodsport
# 64. Cobra
# 65. The Delta Force
# 66. Lat sau san taam
# 67. Ying hung boon sik
# 68. Dip huet seung hung
# 69. Wo hu cang long
# 70. Jui kuen II
# 71. Hung fan kui
# 72. Ong-Bak
# 73. Meng long guo jiang
# 74. Road House
# 75. Enter the Dragon
# 76. Jing wu men
# 77. The Warriors
# 78. Assault on Precinct 13
# 79. Escape from New York
# 80. Bullitt
# 81. Goldfinger
# 82. Desperado
# 83. Beverly Hills Cop
# 84. 48 Hrs.
# 85. Highlander
# 86. Die Hard 2
# 87. Atomic Blonde
# 88. Upgrade
# 89. Mission: Impossible - Rogue Nation
# 90. Mission: Impossible - Fallout
# 91. Dredd
# 92. Kingsman: The Secret Service
# 93. 300
# 94. Fast Five
# 95. Crank
# 96. The Transporter
# 97. Bad Boys II
# 98. Snowpiercer
# 99. Where Eagles Dare
# 100. The Dirty Dozen

# %%
movie_titles
# Out:
# ['Die Hard',
#  'Raiders of the Lost Ark',
#  'Indiana Jones and the Temple of Doom',
#  'Indiana Jones and the Last Crusade',
#  'Terminator 2: Judgment Day',
#  'Predator',
#  'Mad Max 2',
#  'RoboCop',
#  'Aliens',
#  'Point Break',
#  'The Rock',
#  'Lethal Weapon',
#  'Speed',
#  'First Blood',
#  'Commando',
#  'Total Recall',
#  'Die Hard with a Vengeance',
#  'Con Air',
#  'Face/Off',
#  'True Lies',
#  'Big Trouble in Little China',
#  'Last Action Hero',
#  'They Live',
#  'The Terminator',
#  'The Matrix',
#  'Rambo: First Blood Part II',
#  'The Mummy',
#  'The Running Man',
#  'The Last Boy Scout',
#  'Pirates of the Caribbean: The Curse of the Black Pearl',
#  'The Dark Knight',
#  'Tango & Cash',
#  'Casino Royale',
#  'Mad Max: Fury Road',
#  'The Bourne Identity',
#  'The Bourne Supremacy',
#  'The Bourne Ultimatum',
#  'Kill Bill: Vol. 2',
#  'Kill Bill: Vol. 1',
#  'Skyfall',
#  'John Wick',
#  'John Wick: Chapter 2',
#  'John Wick: Chapter 3 - Parabellum',
#  'Mission: Impossible - Ghost Protocol',
#  'Serbuan maut',
#  'Serbuan maut 2: Berandal',
#  'Taken',
#  'Inception',
#  'Top Gun: Maverick',
#  'Top Gun',
#  'Léon',
#  'Heat',
#  'The Fugitive',
#  'Under Siege',
#  'Cliffhanger',
#  'Demolition Man',
#  'Independence Day',
#  'The Long Kiss Goodnight',
#  'Armageddon',
#  'Air Force One',
#  'Red Heat',
#  'Timecop',
#  'Bloodsport',
#  'Cobra',
#  'The Delta Force',
#  'Lat sau san taam',
#  'Ying hung boon sik',
#  'Dip huet seung hung',
#  'Wo hu cang long',
#  'Jui kuen II',
#  'Hung fan kui',
#  'Ong-Bak',
#  'Meng long guo jiang',
#  'Road House',
#  'Enter the Dragon',
#  'Jing wu men',
#  'The Warriors',
#  'Assault on Precinct 13',
#  'Escape from New York',
#  'Bullitt',
#  'Goldfinger',
#  'Desperado',
#  'Beverly Hills Cop',
#  '48 Hrs.',
#  'Highlander',
#  'Die Hard 2',
#  'Atomic Blonde',
#  'Upgrade',
#  'Mission: Impossible - Rogue Nation',
#  'Mission: Impossible - Fallout',
#  'Dredd',
#  'Kingsman: The Secret Service',
#  '300',
#  'Fast Five',
#  'Crank',
#  'The Transporter',
#  'Bad Boys II',
#  'Snowpiercer',
#  'Where Eagles Dare',
#  'The Dirty Dozen']

# %%
import requests
import csv

API_KEY = 'AIzaSyDO6nyT-eTkDqL6QEnyMH-0yTgM-7eJJmo'

def get_youtube_trailer_link(movie_title):
    base_url = 'https://www.googleapis.com/youtube/v3/search'
    params = {
        'key': API_KEY,
        'part': 'snippet',
        'q': f'{movie_title} trailer',
        'type': 'video',
        'maxResults': 1
    }

    response = requests.get(base_url, params=params)
    if response.status_code == 200:
        data = response.json()
        if 'items' in data and len(data['items']) > 0:
            video_id = data['items'][0]['id']['videoId']
            return f'https://www.youtube.com/watch?v={video_id}'
    return None


# Collect trailer links for each movie title
movie_trailer_links = []
for title in movie_titles:
    trailer_link = get_youtube_trailer_link(title)
    movie_trailer_links.append((title, trailer_link))

# Write data to a CSV file
with open('links/action_movies.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['Movie Title', 'Trailer Link'])
    writer.writerows(movie_trailer_links)

print("CSV file created with movie titles and trailer links.")
# Out:
# CSV file created with movie titles and trailer links.
